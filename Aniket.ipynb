# %%
#Data collection from a CSV file
import pandas as pd
csv=pd.read_csv("Iris.csv")
print(csv)
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
#Data collection from Text file
text=open("Iris.csv").read()
print(text)
# Out:
# Id,SepalLengthCm,SepalWidthCm,PetalLengthCm,PetalWidthCm,Species
# 1,5.1,3.5,1.4,0.2,Iris-setosa
# 2,4.9,3.0,1.4,0.2,Iris-setosa
# 3,4.7,3.2,1.3,0.2,Iris-setosa
# 4,4.6,3.1,1.5,0.2,Iris-setosa
# 5,5.0,3.6,1.4,0.2,Iris-setosa
# 6,5.4,3.9,1.7,0.4,Iris-setosa
# 7,4.6,3.4,1.4,0.3,Iris-setosa
# 8,5.0,3.4,1.5,0.2,Iris-setosa
# 9,4.4,2.9,1.4,0.2,Iris-setosa
# 10,4.9,3.1,1.5,0.1,Iris-setosa
# 11,5.4,3.7,1.5,0.2,Iris-setosa
# 12,4.8,3.4,1.6,0.2,Iris-setosa
# 13,4.8,3.0,1.4,0.1,Iris-setosa
# 14,4.3,3.0,1.1,0.1,Iris-setosa
# 15,5.8,4.0,1.2,0.2,Iris-setosa
# 16,5.7,4.4,1.5,0.4,Iris-setosa
# 17,5.4,3.9,1.3,0.4,Iris-setosa
# 18,5.1,3.5,1.4,0.3,Iris-setosa
# 19,5.7,3.8,1.7,0.3,Iris-setosa
# 20,5.1,3.8,1.5,0.3,Iris-setosa
# 21,5.4,3.4,1.7,0.2,Iris-setosa
# 22,5.1,3.7,1.5,0.4,Iris-setosa
# 23,4.6,3.6,1.0,0.2,Iris-setosa
# 24,5.1,3.3,1.7,0.5,Iris-setosa
# 25,4.8,3.4,1.9,0.2,Iris-setosa
# 26,5.0,3.0,1.6,0.2,Iris-setosa
# 27,5.0,3.4,1.6,0.4,Iris-setosa
# 28,5.2,3.5,1.5,0.2,Iris-setosa
# ...

# %%
import pandas as pd
iris=pd.read_csv('iris.csv')
display(iris)
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
iris.shape
# Out:
# (150, 6)

# %%
iris.describe()
# Out:
#                Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  150.000000     150.000000    150.000000     150.000000    150.000000
# mean    75.500000       5.843333      3.054000       3.758667      1.198667
# std     43.445368       0.828066      0.433594       1.764420      0.763161
# min      1.000000       4.300000      2.000000       1.000000      0.100000
# 25%     38.250000       5.100000      2.800000       1.600000      0.300000
# 50%     75.500000       5.800000      3.000000       4.350000      1.300000
# 75%    112.750000       6.400000      3.300000       5.100000      1.800000
# max    150.000000       7.900000      4.400000       6.900000      2.500000

# %%
iris.iloc[5:11,2:]
# Out:
#     SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 5            3.9            1.7           0.4  Iris-setosa
# 6            3.4            1.4           0.3  Iris-setosa
# 7            3.4            1.5           0.2  Iris-setosa
# 8            2.9            1.4           0.2  Iris-setosa
# 9            3.1            1.5           0.1  Iris-setosa
# 10           3.7            1.5           0.2  Iris-setosa

# %%
iris.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
iris.head
# Out:
# <bound method NDFrame.head of       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ...

# %%
iris.min
# Out:
# <bound method NDFrame._add_numeric_operations.<locals>.min of       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# ...

# %%
iris.min()
# Out:
# Id                         1
# SepalLengthCm            4.3
# SepalWidthCm             2.0
# PetalLengthCm            1.0
# PetalWidthCm             0.1
# Species          Iris-setosa
# dtype: object

# %%
iris.max
# Out:
# <bound method NDFrame._add_numeric_operations.<locals>.max of       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# ...

# %%
iris.max()
# Out:
# Id                          150
# SepalLengthCm               7.9
# SepalWidthCm                4.4
# PetalLengthCm               6.9
# PetalWidthCm                2.5
# Species          Iris-virginica
# dtype: object

# %%
iris.mean()
# Out:
# C:\Users\ANKITS~1\AppData\Local\Temp/ipykernel_3680/935066809.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   iris.mean()
# Id               75.500000
# SepalLengthCm     5.843333
# SepalWidthCm      3.054000
# PetalLengthCm     3.758667
# PetalWidthCm      1.198667
# dtype: float64

# %%
iris.median()
# Out:
# C:\Users\ANKITS~1\AppData\Local\Temp/ipykernel_3680/1297003277.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   iris.median()
# Id               75.50
# SepalLengthCm     5.80
# SepalWidthCm      3.00
# PetalLengthCm     4.35
# PetalWidthCm      1.30
# dtype: float64

# %%
iris.mode()
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.0           3.0            1.5           0.2
# 1      2            NaN           NaN            NaN           NaN
# 2      3            NaN           NaN            NaN           NaN
# 3      4            NaN           NaN            NaN           NaN
# 4      5            NaN           NaN            NaN           NaN
# ..   ...            ...           ...            ...           ...
# 145  146            NaN           NaN            NaN           NaN
# 146  147            NaN           NaN            NaN           NaN
# 147  148            NaN           NaN            NaN           NaN
# 148  149            NaN           NaN            NaN           NaN
# 149  150            NaN           NaN            NaN           NaN
#
#              Species
# 0        Iris-setosa
# 1    Iris-versicolor
# 2     Iris-virginica
# 3                NaN
# 4                NaN
# ..               ...
# ...

# %%
iris.mode
# Out:
# <bound method DataFrame.mode of       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ...

# %%
def double_make(s):
    return s*2

# %%
iris[['sepal length','petal.width']].apply(double_makle_make)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# C:\Users\ANKITS~1\AppData\Local\Temp/ipykernel_7132/1395125171.py in <module>
# ----> 1 iris[['sepal length','petal.width']].apply(double_makle_make)
#
# NameError: name 'iris' is not defined

# %%
iris['species']count
# Out:
#   File "C:\Users\ANKITS~1\AppData\Local\Temp/ipykernel_7132/2545466442.py", line 1
#     iris['species']count
#                    ^
# SyntaxError: invalid syntax

# %%
#Data collection from Text file

text=open("210101120019 eng.txt").read()
print(text)
# Out:
# Struggles forEquality In this book, you have read about people like Kanta, the Ansaris, Melani and Swapna. The thread that connects all of these lives is that they have been treated unequally. What do people do when they face such inequalities? History is full of examples of persons who have come together to fight against inequality and for issues of justice. Do you recall the story of Rosa Parks in Chapter 1? Do you remember the photo-essay on the womenâ€™s movement in Chapter 5? In this chapter you will learn about some of the As you have already read in this book, the Indian Constitution recognises all Indians as equal before the law and states that no person can be discriminated against because of their religion, sex, caste or whether they are rich or poor. All adults in India have the equal right to vote during electionsand this â€˜power over the ballot boxâ€™ has been used by people to elect or replace their representatives. But this feeling of equality that the ballot box prov
# ...

# %%
#Data collection from Text file

text=open("").read()
print(text)
